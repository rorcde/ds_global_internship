# %%
import pandas as pd

# %%
train = pd.read_csv('../data/01_train_70pct_crypto_1583_2013-2019.csv')

test = pd.read_csv('../data/02_test_30pct_crypto_1583_2013-2019.csv')

# %%
train = train.set_index(['Coin', 'Date'])
test = test.set_index(['Coin', 'Date'])

# %%
train.columns.values
# Out:
# array(['Open*', 'High', 'Low', 'Close**', 'Volume', 'Market Cap'],
#       dtype=object)

# %%
train.loc['bitcoin']['Close**'].plot()
